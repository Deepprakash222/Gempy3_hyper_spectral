# %%
import numpy as np 
import matplotlib.pyplot as plt 
import json

# %%
# Path to the JSON file
file_path = './posterior_samples.json'

# Open and read the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# Now `data` is a Python dictionary containing the parsed JSON
print(data)
# Out:
# {'cov_eigen_values_1': [[-0.16093040679570503, 0.06410400245737, 0.048078446499276506, -0.043477977342141094, -0.033669723196385, -0.030476603480710494, -0.02334070005315224, -0.017094258677715073, 0.015511766175713154, -0.013795454495860622], [-0.16822502365329658, 0.06803407141037275, 0.04818566966948712, -0.05090753758675208, -0.03087046282568655, -0.03531909259642465, -0.025750301033185506, -0.018855466417374157, 0.015166667660180249, -0.011577699917172944], [-0.855513277653226, 0.19604701518071788, 0.11444411859115536, -0.05809978861408721, -0.04178845883793707, -0.03738852672108582, -0.025950579551145436, -0.02112457699038321, 0.013322906526797003, -0.010955024934974984], [-0.8622884886796912, 0.15989565326098476, 0.09638171294464623, -0.07129536430588804, -0.04485613999259091, -0.05025444610371995, -0.027526983377239515, -0.018793143423571433, 0.01398595822761897, -0.010850566581081028], [-0.9107102422023393, 0.0759070893054899, 0.10382277555833991, -0.06634336644548422, -0.03279906755477227, -0.05136987597511291, -0.031936111118700844, -0.022604614965999418, 0.012994483447116992, -0.010558492305941655], [-0.9140005011220169, 0.10354182085202258, 0.050678438340150386, -0.05622391506837838, -0.04675194471341954, -0.034907217128940855, -0.02067532954986383, -0.028225711369728155, 0.010054422635318744, -0.014183396141974133], [-0.9283935219634534, 0.11031989626322962, 0.13075311182900676, -0.05716479847320312, -0.04450379842095895, -0.03769145195274664, -0.03339092528452774, -0.021671484082991806, 0.012842645044789444, -0.015923831219813517], [-0.8124590405325703, 0.11769979806022807, 0.0805495454488368, -0.0535073684307373, -0.04117793255893652, -0.040153681573637134, -0.04107853697775139, -0.024064105204946035, 0.01757076082252244, -0.015987100683194064], [-0.7924827541360087, 0.08442818942624936, 0.08138592202811874, -0.08387767273523121, -0.035513583197895285, -0.04298196715663964, -0.026977427028549567, -0.02395639083817863, 0.011085740956448447, -0.011971704440023998], [-0.6795639411200289, 0.11982250713998124, 0.06707854036281104, -0.04760358029609245, -0.036296674585672616, -0.04729045926073363, -0.029203395328666466, -0.014367304222808805, 0.01110281490080269, -0.014287529989664762], [-0.48345197361815, 0.12795727725647055, 0.08366532976791258, -0.07051045555061886, -0.04386096273699103, -0.04319248143997915, -0.024296284955131933, -0.019770844110046044, 0.014780881148719071, -0.013342899427033934], [-0.4328219814865994, 0.11721052413129222, 0.07869711211189409, -0.05443432004403382, -0.042904405489113076, -0.030674472688365647, -0.021504999001730914, -0.019813879217565774, 0.00916222122987772, -0.009808988721317607], [-0.39895547950072896, 0.1554588172139814, 0.09086972998491438, -0.0596132340156749, -0.04135524303248697, -0.037636638954169105, -0.01751181262743955, -0.02177294967196835, 0.00946540899848553, -0.013810149907377023], [-0.3033068717492097, 0.10029003468860777, 0.0841852613894932, -0.05417378033831082, -0.05587655980132084, -0.044154969920954495, -0.02979444246383281, -0.021173829827972244, 0.016983839981364292, -0.01248035800718294], [-0.5880288455966909, 0.11741337527933447, 0.08037034066366786, -0.06438304280705301, -0.04978728506691676, -0.05080866267904177, -0.024539125237842668, -0.01937627424225529, 0.015641166559576234, -0.015265920060848284], [-0.5210706427854428, 0.09109827489997448, 0.12460146101787752, -0.056092723650911905, -0.04933581407358863, -0.051124187989088445, -0.02544929337994218, -0.020420115521725492, 0.008965604383996678, -0.01595106614094661], [-0.33648519890610984, 0.10858947904753868, 0.09557426452409835, -0.05799939240937352, -0.0319883286298557, -0.05982698720096355, -0.024773796041034517, -0.01851290829662449, 0.009188028074706905, -0.013546402662159208], [-0.39337791470733713, 0.14096692994605037, 0.09305923405770751, -0.05942954295719292, -0.033913770160207725, -0.0636173194547347, -0.025740624380088395, -0.022039953256391725, 0.010262881592388183, -0.0138234125975736 ...

# %%
for key, values in data.items():
    print(key)
# Out:
# cov_eigen_values_1
# cov_eigen_values_2
# cov_eigen_values_3
# cov_eigen_values_4
# cov_eigen_values_5
# cov_eigen_values_6
# mean_data_1
# mean_data_2
# mean_data_3
# mean_data_4
# mean_data_5
# mean_data_6
# mu_1
# mu_2
# mu_3
# mu_4
# eigen_vectors

# %%
cov_eigen_values_1 = np.array(data['cov_eigen_values_1'])
cov_eigen_values_2 = np.array(data['cov_eigen_values_2'])
cov_eigen_values_3 = np.array(data['cov_eigen_values_3'])
cov_eigen_values_4 = np.array(data['cov_eigen_values_4'])
cov_eigen_values_5 = np.array(data['cov_eigen_values_5'])
cov_eigen_values_6 = np.array(data['cov_eigen_values_6'])
mean_data_1        = np.array(data['mean_data_1'])
mean_data_2        = np.array(data['mean_data_2'])
mean_data_3        = np.array(data['mean_data_3'])
mean_data_4        = np.array(data['mean_data_4'])
mean_data_5        = np.array(data['mean_data_5'])
mean_data_6        = np.array(data['mean_data_6'])
eigen_vectors      = np.array(data["eigen_vectors"])
mu_1               = np.array(data["mu_1"])
mu_2               = np.array(data["mu_2"])
mu_3               = np.array(data["mu_3"])
mu_4               = np.array(data["mu_4"])

# %%
mean_mu_1 = np.mean(mu_1)
std_mu_1 = np.std(mu_1)
mean_mu_2 = np.mean(mu_2)
std_mu_2 = np.std(mu_2)
mean_mu_3 = np.mean(mu_3)
std_mu_3 = np.std(mu_3)
mean_mu_4 = np.mean(mu_4)
std_mu_4 = np.std(mu_4)
mean_mu_1, std_mu_1, mean_mu_2, std_mu_2, mean_mu_3, std_mu_3,mean_mu_4, std_mu_4
# Out:
# (3.3703704814197093,
#  0.1217592401939015,
#  2.3615091385923663,
#  0.1327238100103672,
#  1.1981682536332778,
#  0.12310847823274265,
#  0.2362484944924049,
#  0.10189866181281272)

# %%
mean_mean_1 = np.mean(mean_data_1, axis=0)
mean_std_1 = np.std(mean_data_1, axis=0)
mean_mean_2 = np.mean(mean_data_2, axis=0)
mean_std_2= np.std(mean_data_2, axis=0)
mean_mean_3 = np.mean(mean_data_3, axis=0)
mean_std_3 = np.std(mean_data_3, axis=0)
mean_mean_4 = np.mean(mean_data_4, axis=0)
mean_std_4 = np.std(mean_data_4, axis=0)
mean_mean_5 = np.mean(mean_data_5, axis=0)
mean_std_5 = np.std(mean_data_5, axis=0)
mean_mean_6 = np.mean(mean_data_6, axis=0)
mean_std_6 = np.std(mean_data_6, axis=0)

# %%
cov_1 = []
for i in range(cov_eigen_values_1.shape[0]):
    cov = eigen_vectors[0] @ np.diag(cov_eigen_values_1[i,:])**2 @ eigen_vectors[0].T
    cov_1.append(cov)
cov_1 = np.array(cov_1)
mean_cov_1 = np.mean(cov_1,axis=0)
std_cov_1 = np.std(cov_1,axis=0)
mean_cov_1.shape, std_cov_1.shape
# Out:
# ((10, 10), (10, 10))

# %%
cov_2 = []
for i in range(cov_eigen_values_2.shape[0]):
    cov = eigen_vectors[1] @ np.diag(cov_eigen_values_2[i,:])**2 @ eigen_vectors[1].T
    cov_2.append(cov)
cov_2 = np.array(cov_2)
mean_cov_2 = np.mean(cov_2,axis=0)
std_cov_2 = np.std(cov_2,axis=0)
mean_cov_2.shape, std_cov_2.shape
# Out:
# ((10, 10), (10, 10))

# %%
cov_3 = []
for i in range(cov_eigen_values_2.shape[0]):
    cov = eigen_vectors[2] @ np.diag(cov_eigen_values_3[i,:])**2 @ eigen_vectors[2].T
    cov_3.append(cov)
cov_3 = np.array(cov_3)
mean_cov_3 = np.mean(cov_3,axis=0)
std_cov_3 = np.std(cov_3,axis=0)
mean_cov_3.shape, std_cov_3.shape
# Out:
# ((10, 10), (10, 10))

# %%
cov_4 = []
for i in range(cov_eigen_values_2.shape[0]):
    cov = eigen_vectors[3] @ np.diag(cov_eigen_values_4[i,:])**2 @ eigen_vectors[3].T
    cov_4.append(cov)
cov_4 = np.array(cov_4)
mean_cov_4 = np.mean(cov_4,axis=0)
std_cov_4 = np.std(cov_4,axis=0)
mean_cov_4.shape, std_cov_4.shape
# Out:
# ((10, 10), (10, 10))

# %%
cov_5 = []
for i in range(cov_eigen_values_2.shape[0]):
    cov = eigen_vectors[4] @ np.diag(cov_eigen_values_5[i,:])**2 @ eigen_vectors[4].T
    cov_5.append(cov)
cov_5 = np.array(cov_5)
mean_cov_5 = np.mean(cov_5,axis=0)
std_cov_5 = np.std(cov_5,axis=0)
mean_cov_5.shape, std_cov_5.shape
# Out:
# ((10, 10), (10, 10))

# %%
cov_6 = []
for i in range(cov_eigen_values_2.shape[0]):
    cov = eigen_vectors[5] @ np.diag(cov_eigen_values_6[i,:])**2 @ eigen_vectors[5].T
    cov_6.append(cov)
cov_6 = np.array(cov_6)
mean_cov_6 = np.mean(cov_6,axis=0)
std_cov_6 = np.std(cov_6,axis=0)
mean_cov_6.shape, std_cov_6.shape
# Out:
# ((10, 10), (10, 10))

# %%
means =[]
means.append(mean_mean_1)
means.append(mean_mean_2)
means.append(mean_mean_3)
means.append(mean_mean_4)
means.append(mean_mean_5)
means.append(mean_mean_6)

covariances=[]
covariances.append(mean_cov_1)
covariances.append(mean_cov_2)
covariances.append(mean_cov_3)
covariances.append(mean_cov_4)
covariances.append(mean_cov_5)
covariances.append(mean_cov_6)

# %%
from scipy.stats import multivariate_normal

# %%
K = 6 # Number of cluster
D = len(means[0])  # 8 Dimesion of feature space

n =3 # how far in terms of std you want to plot

# Create a figure and a set of subplots
fig, axes = plt.subplots(nrows=D, ncols=D, figsize=(15, 15))
label_to_color = { 0: 'red', 1: 'blue', 2: 'green', 3: 'yellow', 4: 'orange', 5: 'purple'}

for i in range(K):
    # Create different plot of each cluster
    for j in range(D):
        for k in range(D):
            if j==k:
                mean_ = np.array([means[i][j],means[i][k]])
                cov_  = np.diag([covariances[i][j][j], covariances[i][k][k]])
                
                # Create a grid of points
                x, y = np.meshgrid(np.linspace(mean_[0] -n * np.sqrt(cov_[0][0]), mean_[0] +n * np.sqrt(cov_[0][0]), 1000), np.linspace(mean_[1]-n * np.sqrt(cov_[1][1]), mean_[1]+ n * np.sqrt(cov_[1][1]), 1000))
                pos = np.dstack((x, y))
                # Create the multivariate normal distribution
                rv = multivariate_normal(mean_, cov_)
                # Compute the probability density function (PDF) at the grid points
                pdf = rv.pdf(pos)
                axes[j][k].contour(x, y, pdf, levels=1,colors=label_to_color[i], linewidths=2)
                
                
            else:
                mean_ = np.array([means[i][j],means[i][k]])
                cov_  = np.array([[covariances[i][j][j],covariances[i][j][k]],[covariances[i][k][j], covariances[i][k][k]]])
                
                # Create a grid of points
                x, y = np.meshgrid(np.linspace(mean_[0] -n * np.sqrt(cov_[0][0]), mean_[0] +n * np.sqrt(cov_[0][0]), 1000), np.linspace(mean_[1]-n * np.sqrt(cov_[1][1]), mean_[1]+ n * np.sqrt(cov_[1][1]), 1000))
                pos = np.dstack((x, y))
                # Create the multivariate normal distribution
                rv = multivariate_normal(mean_, cov_)
                # Compute the probability density function (PDF) at the grid points
                pdf = rv.pdf(pos)
                axes[j][k].contour(x, y, pdf, levels=1, colors=label_to_color[i], linewidths=2)
                
            #
                
            if j==0:
                axes[j][k].set_title(f'feature_{k+1}')
            if k==0:
                axes[j][k].set_ylabel(f'feature_{j+1}')
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], color=color, lw=2, label=f'Cluster {i + 1}')
                   for i, color in label_to_color.items()]
# Add a legend
lines = [] 
labels = [] 
  
for ax in fig.axes: 
    Line, Label = ax.get_legend_handles_labels() 
    lines.extend(Line) 
    labels.extend(Label)
fig.legend(handles=legend_elements, loc='upper right', title='Cluster Legend')

plt.show()
